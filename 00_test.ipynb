# %%
print("akanksha")
# Out:
# akanksha

# %%
name = input("Enter your name: ")
print("Hello, " + name + "! Welcome to the program.")
# Out:
# Hello, akanksha! Welcome to the program.

# %%
C
marks = int(input("Enter your marks: "))
if marks > 95:
    print("Grade A")
elif marks > 85:        
    print("Grade B")
elif marks > 75:
    print("Grade C")
elif marks > 65:
    print("Grade D")
elif marks > 55:
    print("Grade E")
else:
    print("Grade F")
# Out:
# Grade B
